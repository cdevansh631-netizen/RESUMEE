# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("cars.xls")

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.tail()
# Out:
#                           name    company  year     Price  kms_driven  \
# 887                         Ta       Tara  zest  3,10,000         NaN
# 888        Tata Zest XM Diesel       Tata  2018  2,60,000  27,000 kms
# 889         Mahindra Quanto C8   Mahindra  2013  3,90,000  40,000 kms
# 890   Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000      Petrol
# 891  Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000      Petrol
#
#     fuel_type
# 887       NaN
# 888    Diesel
# 889    Diesel
# 890       NaN
# 891       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df["name"].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
backup=df.copy()

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df=df[df["year"].str.isnumeric()]

# %%
df.head(2)
# Out:
#                                    name   company  year     Price  kms_driven  \
# 0  Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000  45,000 kms
# 1               Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000      40 kms
#
#   fuel_type
# 0    Petrol
# 1    Diesel

# %%
df["name"]=df["name"].str.split().str[:3].str.join(" ")

# %%
df["company"].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Force', 'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'],
#       dtype=object)

# %%
df["year"]=df["year"].astype(int)

# %%
df["Price"]=df["Price"].dropna()

# %%
df=df[df["Price"]!="Ask For Price"]

# %%
df["Price"]=df["Price"].str.replace(",","").astype(int)

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
df['kms_driven']=df['kms_driven'].str.split().str.get(0).str.replace(',','')

# %%
df=df[df['kms_driven'].str.isnumeric()]

# %%
df['kms_driven']=df['kms_driven'].astype(int)

# %%
df["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
df=df.dropna(subset=["fuel_type"])

# %%
df=df.reset_index(drop=True)

# %%
df.describe()
# Out:
#               year         Price     kms_driven
# count   816.000000  8.160000e+02     816.000000
# mean   2012.444853  4.117176e+05   46275.531863
# std       4.002992  4.751844e+05   34297.428044
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.912500e+05   56818.500000
# max    2019.000000  8.500003e+06  400000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.4+ KB

# %%
plt.figure(figsize=(19,7))

plt.subplot(1,3,1)
plt.boxplot(df["Price"],showmeans=True,meanline=True)
plt.title("Price")

plt.subplot(1,3,2)
plt.boxplot(df["year"],showmeans=True,meanline=True)
plt.title("Year")

plt.subplot(1,3,3)
plt.boxplot(df["kms_driven"],showmeans=True,meanline=True)
plt.title("kms_driven")
# Out:
# Text(0.5, 1.0, 'kms_driven')

# %%
plt.scatter(df["Price"],df["kms_driven"])
plt.xlabel("PRICE")
plt.ylabel("KMS_DRIVEN")
# Out:
# Text(0, 0.5, 'KMS_DRIVEN')

# %%
df.groupby("year").agg({"year":"count"})
# Out:
#       year
# year
# 1995     2
# 2000     7
# 2001     5
# 2002     4
# 2003    13
# 2004    12
# 2005    13
# 2006    22
# 2007    19
# 2008    16
# 2009    54
# 2010    43
# 2011    59
# 2012    75
# 2013    94
# 2014    92
# 2015   111
# 2016    74
# 2017    53
# 2018    30
# 2019    18

# %%
df["fuel_type"].value_counts().plot(kind="pie",autopct="%1.1f",wedgeprops={"edgecolor":"black","linewidth":0.7})
# Out:
# <Axes: ylabel='count'>

# %%
df["company"].value_counts().plot(kind="pie",autopct="%1.1f",wedgeprops={"edgecolor":"black",})
# Out:
# <Axes: ylabel='count'>

# %%
df["company"].value_counts().head()
# Out:
# company
# Maruti      221
# Hyundai     139
# Mahindra     98
# Tata         65
# Honda        60
# Name: count, dtype: int64

# %%
df["company"].value_counts().tail()
# Out:
# company
# Hindustan    3
# Jaguar       2
# Land         1
# Jeep         1
# Volvo        1
# Name: count, dtype: int64

# %%
X=df.drop(columns="Price")
Y=df["Price"]

# %%
X.columns
# Out:
# Index(['name', 'company', 'year', 'kms_driven', 'fuel_type'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
A=ColumnTransformer([("Encoder",OneHotEncoder(handle_unknown="ignore"),["name","company","fuel_type"])],remainder="passthrough")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
lr=LinearRegression()

# %%
from sklearn.pipeline import make_pipeline
pipe=make_pipeline(A,lr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.17311145503634873

# %%
M=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(A,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    M.append(r2_score(y_test,y_pred))

# %%
np.argmax(M)
# Out:
# np.int64(247)

# %%
M[np.argmax(M)]
# Out:
# 0.8604434814526677

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2012,100,'Diesel']).reshape(1,5)))
# Out:
# array([363492.10805617])

# %%
import pickle
pickle.dump(pipe,open("Working_File.pkl",'wb'))
